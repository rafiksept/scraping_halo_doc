# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.core.os_manager import ChromeType
from selenium.webdriver.chrome.options import Options
import pandas as pd
from bs4 import BeautifulSoup

user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
chrome_options = Options()
options = [
    f"--user-agent={user_agent}"
]
for option in options:
    chrome_options.add_argument(option)

# %%
df = pd.read_csv("name_obat_fix.csv")
df
# Out:
#        Unnamed: 0.1  Unnamed: 0  \
# 0                 0           0
# 1                 1           1
# 2                 2           2
# 3                 3           3
# 4                 4           4
# ...             ...         ...
# 17731         17731       17731
# 17732         17732       17732
# 17733         17733       17733
# 17734         17734       17734
# 17735         17735       17735
#
#                                                     name          category
# 0                      Sildenafil-Citrate-50-mg-4-Tablet  disfungsi-ereksi
# 1                                  Viagra-50-mg-1-Tablet  disfungsi-ereksi
# 2                                  Ericfil-Tablet-100-mg  disfungsi-ereksi
# 3                                    Cialis-Tablet-10-mg  disfungsi-ereksi
# 4                                      Ericfil-50-mg-Odf  disfungsi-ereksi
# ...                                                  ...               ...
# 17731    Battery-Tester-Alat-Bantu-Dengar--Hearing-Aids-         aksesoris
# 17732                              Selang-Tubing-Melawai         aksesoris
# 17733  Serenity-Battery-1-45-V-Type-13-For-Hearing-Ai...         aksesoris
# 17734                      Serenity-Hearing-Aid-SR-80BTE         aksesoris
# 17735                        Serenity-Hearing-Aid-SR-80P         aksesoris
#
# [17736 rows x 4 columns]

# %%
name_array = []
price_array = []
deksripsi_array = []
isi_deksripsi_array = []


for i in range(1000, 1001):
    name = df["name"][i]
    print(f"Index ke - {i} Ambil data - {name}")
    url = f"https://www.halodoc.com/obat-dan-vitamin/{name}"

    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
    driver.get(url)

    try :
        tunggu =  WebDriverWait(driver, 30).until(EC.visibility_of_element_located((By.CSS_SELECTOR, '.drug-detail')))
    except :
        print("tidak ada elemen nya!")
        continue

    try :
        nama_obat = driver.find_elements(By.CSS_SELECTOR, ".product-label")
        name_array.append(nama_obat[0].text)
    except :
        print(name + "tidak ada nama!")
        continue

    try :
        harga = driver.find_elements(By.CSS_SELECTOR, ".product-price")
        price_array.append(harga[0].text)
    except :
        print(name + "tidak ada harga")
        price_array.append("noValue")

    try :
        deskripsi = driver.find_elements(By.CSS_SELECTOR, ".ttl-list")
        deksripsi_array.append
        teks_deksripsi = []

        for i in range(0, len(deskripsi)):
            teks_deksripsi.append(deskripsi[i].text)

        deksripsi_string = "**".join(teks_deksripsi)
        deksripsi_array.append(deksripsi_string)

        isi_deksripsi = driver.find_elements(By.CSS_SELECTOR, ".drug-detail")
        teks_isi_deksripsi = []

        for i in range(0, len(isi_deksripsi)):
            teks_isi_deksripsi.append(isi_deksripsi[i].text)

        isi_deksripsi_string = "**".join(teks_isi_deksripsi)
        isi_deksripsi_array.append(isi_deksripsi_string)


    except :
        print(name + "tidak ada deskripsi")
        deksripsi_array.append("noValue")
        isi_deksripsi_array.append("noValue")

    driver.close()
# Out:
# Index ke - 1000 Ambil data - Buds-Organics-Toothpaste-With-Fluoride-Green-Apple-3-12-Tahun-50-ml

# %%
df_obat = pd.DataFrame({
    "name" : name_array,
    "price" : price_array,
    "deskripsi" : deksripsi_array,
    "isi_deksripsi" : isi_deksripsi_array 
})

df_obat
# Out:
#                                                   name                price  \
# 0    Buds Organics Toothpaste With Fluoride Green A...            Rp149.900
# 1    Buds Organics Toothpaste With Fluoride Strawbe...            Rp149.900
# 2    Buds Organics Toothpaste With Xylitol Blackcur...            Rp149.900
# 3    Buds Organics Toothpaste With Xylitol Green Ap...            Rp149.900
# 4    Buds Organics Toothpaste With Xylitol Strawber...            Rp149.900
# ..                                                 ...                  ...
# 786                  Wetkins Baby Wipes Pink 50 Sheets  Rp14.800 - Rp19.300
# 787                          Baby Choice Original 50 g  Rp35.400 - Rp38.500
# 788                              Bebenice Rusks Banana  Rp27.300 - Rp29.700
# 789                              Bebenice Rusks Carrot  Rp27.300 - Rp29.700
# 790                            Bebenice Rusks Original  Rp27.300 - Rp29.700
#
#                                              deskripsi  \
# 0    Deskripsi**Dosis**Aturan Pakai**Golongan Produ...
# 1    Deskripsi**Dosis**Aturan Pakai**Golongan Produ...
# 2    Deskripsi**Dosis**Aturan Pakai**Golongan Produ...
# 3    Deskripsi**Dosis**Aturan Pakai**Golongan Produ...
# 4    Deskripsi**Dosis**Aturan Pakai**Golongan Produ...
# ..                                                 ...
# 786               Golongan Produk**Kemasan**Manufaktur
# 787                        Golongan Produk**Manufaktur
# 788               Golongan Produk**Kemasan**Manufaktur
# 789               Golongan Produk**Kemasan**Manufaktur
# 790               Golongan Produk**Kemasan**Manufaktur
#
#                                          isi_deksripsi
# 0    Buds Organics Toothpaste With Fluoride merupak...
# 1    Buds Organics Toothpaste With Fluoride merupak...
# 2    Buds Organics Toothpaste With Xylitol merupaka...
# 3    Buds Organics Toothpaste With Xylitol merupaka...
# 4    Buds Organics Toothpaste With Xylitol merupaka...
# ..                                                 ...
# 786  Produk Konsumen**Pack, aluminium foil @ 50 lem...
# 787                   Pangan Olahan Diet Khusus**Empro
# 788               Pangan Olahan Diet Khusus**Dus**None
# 789               Pangan Olahan Diet Khusus**Dus**None
# 790               Pangan Olahan Diet Khusus**Dus**None
#
# [791 rows x 4 columns]

# %%
df_obat.to_csv("data_obat4.csv")

# %%
df["name"][536]
# Out:
# 'Boost-Optimum-800-g'
